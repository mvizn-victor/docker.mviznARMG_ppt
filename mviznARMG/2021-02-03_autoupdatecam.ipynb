# %%
import glob
preset_folder=glob.glob('/home/mvizn/*Preset')[0]
folder=preset_folder
import configparser
def read_seoho_preset_folder(folder):
    pan=dict()
    tilt=dict()
    config=configparser.ConfigParser()
    config.read(f'{folder}/LS_Center_Preset.ini')
    pan['cnlsbc']=float(config['Center']['LS_Center_Pan_Offset'])
    tilt['cnlsbc']=float(config['Center']['LS_Center_Tilt_Offset'])
    config=configparser.ConfigParser()
    config.read(f'{folder}/LS_Front_Preset.ini')
    pan['cnlsbf']=float(config['Front']['LS_Front_Pan_Offset'])
    tilt['cnlsbf']=float(config['Front']['LS_Front_Tilt_Offset'])
    config=configparser.ConfigParser()
    config.read(f'{folder}/LS_Rear_Preset.ini')
    pan['cnlsbb']=float(config['Rear']['LS_Rear_Pan_Offset'])
    tilt['cnlsbb']=float(config['Rear']['LS_Rear_Tilt_Offset'])
    config=configparser.ConfigParser()
    config=configparser.ConfigParser()
    config.read(f'{folder}/SS_Center_Preset.ini')
    pan['cnssbc']=float(config['Center']['SS_Center_Pan_Offset'])
    tilt['cnssbc']=float(config['Center']['SS_Center_Tilt_Offset'])
    config=configparser.ConfigParser()
    config.read(f'{folder}/SS_Front_Preset.ini')
    pan['cnssbf']=float(config['Front']['SS_Front_Pan_Offset'])
    tilt['cnssbf']=float(config['Front']['SS_Front_Tilt_Offset'])
    config=configparser.ConfigParser()
    config.read(f'{folder}/SS_Rear_Preset.ini')
    pan['cnssbb']=float(config['Rear']['SS_Rear_Pan_Offset'])
    tilt['cnssbb']=float(config['Rear']['SS_Rear_Tilt_Offset'])
    config=configparser.ConfigParser()
    config.read(f'{folder}/Misc_Preset.ini')
    pan['ovls']=float(config['PM_Camera']['LS_PM_Pan'])
    tilt['ovls']=float(config['PM_Camera']['LS_PM_Tilt'])
    pan['ovss']=float(config['PM_Camera']['SS_PM_Pan'])
    tilt['ovss']=float(config['PM_Camera']['SS_PM_Tilt'])
    return pan,tilt

# %%
import os
pan,tilt=read_seoho_preset_folder(preset_folder)
os.makedirs('config/seoho_offsets/tcds',exist_ok=True)
os.makedirs('config/seoho_offsets/clps',exist_ok=True)
os.makedirs('config/seoho_offsets/pmnrs',exist_ok=True)
def getcamname(f):
    for camname in ['cnlsbf','cnlsbb','cnlsbc','cnssbf','cnssbb','cnssbc','ovls','ovss']:
        if camname in f:
            return camname
    raise Exception(f'{f} does not contain camname')
def getptz(f):
    p,t,z=open(f).read().split('\n')[:3]
    p=float(p.split('=')[1])
    t=float(t.split('=')[1])
    z=int(float(z.split('=')[1]))
    return p,t,z
for f in glob.glob('config/pmnrs/*.txt')+glob.glob('config/clps/*.txt')+glob.glob('config/tcds/*.txt'):
    camname=getcamname(f)
    p,t,z=getptz(f)
    p='%.2f'%(p-pan[camname])
    t='%.2f'%(t-tilt[camname])
    z=z
    ptz=f'pan={p}\ntilt={t}\nzoom={z}'
    print(f,camname)    
    fout=f.replace('config/','config/seoho_offsets/')
    assert 'seoho' in fout
    print(ptz)
    print(ptz,file=open(fout,'w'))

# %%
import os
pan,tilt=read_seoho_preset_folder(preset_folder)
os.makedirs('config/tcds',exist_ok=True)
os.makedirs('config/clps',exist_ok=True)
os.makedirs('config/pmnrs',exist_ok=True)
def getcamname(f):
    for camname in ['cnlsbf','cnlsbb','cnlsbc','cnssbf','cnssbb','cnssbc','ovls','ovss']:
        if camname in f:
            return camname
    raise Exception(f'{f} does not contain camname')
def getptz(f):
    p,t,z=open(f).read().split('\n')[:3]
    p=float(p.split('=')[1])
    t=float(t.split('=')[1])
    z=int(float(z.split('=')[1]))
    return p,t,z
for f in glob.glob('config/seoho_offsets/pmnrs/*.txt')+glob.glob('config/seoho_offsets/clps/*.txt')+glob.glob('config/seoho_offsets/tcds/*.txt'):
    camname=getcamname(f)
    p,t,z=getptz(f)
    p='%.2f'%(p+pan[camname])
    t='%.2f'%(t+tilt[camname])
    z=z
    ptz=f'pan={p}\ntilt={t}\nzoom={z}'
    print(f,camname)
    fout=f.replace('config/seoho_offsets/','config/')
    assert 'seoho' not in fout
    print(fout)
    print(ptz)
    print(ptz,file=open(fout,'w'))
# Out:
# config/seoho_offsets/pmnrs/ovss.txt ovss
# config/pmnrs/ovss.txt
# pan=60.00
# tilt=-92.00
# zoom=900
# config/seoho_offsets/pmnrs/ovls.txt ovls
# config/pmnrs/ovls.txt
# pan=-60.00
# tilt=-92.00
# zoom=900
# config/seoho_offsets/clps/cnlsbb45.txt cnlsbb
# config/clps/cnlsbb45.txt
# pan=-27.00
# tilt=-74.00
# zoom=1
# config/seoho_offsets/clps/cnssbb20.txt cnssbb
# config/clps/cnssbb20.txt
# pan=146.00
# tilt=-48.00
# zoom=1
# config/seoho_offsets/clps/cnssbb40.txt cnssbb
# config/clps/cnssbb40.txt
# pan=146.00
# tilt=-74.00
# zoom=1
# config/seoho_offsets/clps/cnlsbf40.txt cnlsbf
# config/clps/cnlsbf40.txt
# pan=149.00
# tilt=-74.00
# zoom=1
# config/seoho_offsets/clps/cnlsbf45.txt cnlsbf
# config/clps/cnlsbf45.txt
# pan=149.00
# tilt=-74.00
# zoom=1
# config/seoho_offsets/clps/cnlsbb20.txt cnlsbb
# config/clps/cnlsbb20.txt
# pan=-27.00
# tilt=-56.00
# zoom=1
# config/seoho_offsets/clps/cnlsbb40.txt cnlsbb
# config/clps/cnlsbb40.txt
# pan=-27.00
# tilt=-74.00
# zoom=1
# config/seoho_offsets/clps/cnssbc20.txt cnssbc
# config/clps/cnssbc20.txt
# pan=161.00
# tilt=-45.00
# zoom=1
# config/seoho_offsets/clps/cnssbf20.txt cnssbf
# config/clps/cnssbf20.txt
# pan=87.00
# tilt=-48.00
# zoom=1
# config/seoho_offsets/clps/cnssbf40.txt cnssbf
# config/clps/cnssbf40.txt
# pan=88.00
# tilt=-74.00
# zoom=1
# config/seoho_offsets/clps/cnssbf45.txt cnssbf
# config/clps/cnssbf45.txt
# pan=88.00
# tilt=-74.00
# zoom=1
# config/seoho_offsets/clps/cnssbb45.txt cnssbb
# config/clps/cnssbb45.txt
# pan=146.00
# tilt=-74.00
# zoom=1
# config/seoho_offsets/clps/cnlsbf20.txt cnlsbf
# config/clps/cnlsbf20.txt
# pan=149.00
# tilt=-48.00
# zoom=1
# config/seoho_offsets/tcds/cnlsbb45-2.txt cnlsbb
# config/tcds/cnlsbb45-2.txt
# pan=17.00
# tilt=8.00
# zoom=1
# config/seoho_offsets/tcds/cnssbf45-1.txt cnssbf
# config/tcds/cnssbf45-1.txt
# pan=120.00
# tilt=8.00
# zoom=75
# config/seoho_offsets/tcds/cnssbb40-1.txt cnssbb
# config/tcds/cnssbb40-1.txt
# pan=149.00
# tilt=8.00
# zoom=25
# config/seoho_offsets/tcds/cnssbc40.txt cnssbc
# config/tcds/cnssbc40.txt
# pan=105.00
# tilt=-0.00
# zoom=1380
# config/seoho_offsets/tcds/cnssbb20.txt cnssbb
# config/tcds/cnssbb20.txt
# pan=149.00
# tilt=8.00
# zoom=300
# config/seoho_offsets/tcds/cnlsbc40.txt cnlsbc
# config/tcds/cnlsbc40.txt
# pan=-135.00
# tilt=-0.00
# zoom=300
# config/seoho_offsets/tcds/cnlsbb45-1.txt cnlsbb
# config/tcds/cnlsbb45-1.txt
# pan=17.00
# tilt=8.00
# zoom=1
# config/seoho_offsets/tcds/cnlsbb20.txt cnlsbb
# config/tcds/cnlsbb20.txt
# pan=-29.00
# tilt=10.00
# zoom=300
# config/seoho_offsets/tcds/cnlsbc20.txt cnlsbc
# config/tcds/cnlsbc20.txt
# pan=167.00
# tilt=-0.00
# zoom=300
# config/seoho_offsets/tcds/cnlsbf45-2.txt cnlsbf
# config/tcds/cnlsbf45-2.txt
# pan=179.00
# tilt=8.00
# zoom=75
# config/seoho_offsets/tcds/cnlsbb40-1.txt cnlsbb
# config/tcds/cnlsbb40-1.txt
# pan=17.00
# tilt=8.00
# zoom=1
# config/seoho_offsets/tcds/cnssbc45.txt cnssbc
# config/tcds/cnssbc45.txt
# pan=105.00
# tilt=-0.00
# zoom=1380
# config/seoho_offsets/tcds/cnssbb45-1.txt cnssbb
# config/tcds/cnssbb45-1.txt
# pan=119.00
# tilt=8.00
# zoom=75
# config/seoho_offsets/tcds/cnssbf45-2.txt cnssbf
# config/tcds/cnssbf45-2.txt
# pan=60.00
# tilt=8.00
# zoom=75
# config/seoho_offsets/tcds/cnlsbf40-1.txt cnlsbf
# config/tcds/cnlsbf40-1.txt
# pan=149.00
# tilt=8.00
# zoom=25
# config/seoho_offsets/tcds/cnlsbc45.txt cnlsbc
# config/tcds/cnlsbc45.txt
# pan=-135.00
# tilt=-0.00
# zoom=300
# config/seoho_offsets/tcds/cnssbc20.txt cnssbc
# config/tcds/cnssbc20.txt
# pan=167.00
# tilt=-0.00
# zoom=300
# config/seoho_offsets/tcds/cnssbf40-2.txt cnssbf
# config/tcds/cnssbf40-2.txt
# pan=88.00
# tilt=8.00
# zoom=25
# config/seoho_offsets/tcds/cnssbf20.txt cnssbf
# config/tcds/cnssbf20.txt
# pan=88.00
# tilt=8.00
# zoom=300
# config/seoho_offsets/tcds/cnssbf40-1.txt cnssbf
# config/tcds/cnssbf40-1.txt
# pan=88.00
# tilt=8.00
# zoom=25
# config/seoho_offsets/tcds/cnlsbb40-2.txt cnlsbb
# config/tcds/cnlsbb40-2.txt
# pan=17.00
# tilt=8.00
# zoom=1
# config/seoho_offsets/tcds/cnlsbf45-1.txt cnlsbf
# config/tcds/cnlsbf45-1.txt
# pan=119.00
# tilt=8.00
# zoom=75
# config/seoho_offsets/tcds/cnlsbf20.txt cnlsbf
# config/tcds/cnlsbf20.txt
# pan=149.00
# tilt=10.00
# zoom=300
# config/seoho_offsets/tcds/cnssbb40-2.txt cnssbb
# config/tcds/cnssbb40-2.txt
# pan=149.00
# tilt=8.00
# zoom=25
# config/seoho_offsets/tcds/cnssbb45-2.txt cnssbb
# config/tcds/cnssbb45-2.txt
# pan=119.00
# tilt=8.00
# zoom=75
# config/seoho_offsets/tcds/cnlsbf40-2.txt cnlsbf
# config/tcds/cnlsbf40-2.txt
# pan=149.00
# tilt=8.00
# zoom=25
